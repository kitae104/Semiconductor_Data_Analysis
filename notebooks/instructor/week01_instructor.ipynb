# %% [markdown]
# # 1차시 강사용 Notebook — 반도체 공정과 데이터 처음 만나기 + 변수·출력
#
# 학생용 Notebook과 동일한 흐름이며, 예상 결과와 설명 포인트를 함께 담았습니다.
#
# 오늘은 Pandas 없이 진행합니다(Pandas는 4차시부터). 강의 자료에서 데이터를 눈으로 미리 살펴본 뒤,
# 그 결과(합격 32건/불합격 8건)를 변수에 저장하는 것으로 시작합니다.

# %% [markdown]
# ## 1단계. 변수 만들고 값 확인하기
# **설명 포인트**: `=`는 수학의 '같다'가 아니라 대입 연산자임을 강조. 칠판에 상자 그림을 그려 '오른쪽 값이 왼쪽 이름의 상자에 들어간다'고 설명하면 효과적.

# %%
pass_count = 32
fail_count = 8
print(pass_count)
print(fail_count)
# Out:
# 32
# 8

# %% [markdown]
# ## 2단계. f-string으로 문장 만들기
# **어려워할 부분**: 문자열 앞의 `f`를 빼먹으면 중괄호가 그대로 출력된다는 점을 `print("합격 {pass_count}건")`과 비교해 직접 보여주면 효과적.

# %%
print(f"합격 {pass_count}건, 불합격 {fail_count}건입니다.")
# Out:
# 합격 32건, 불합격 8건입니다.

# %% [markdown]
# ## 3단계. input()으로 값 입력받기
# **시연 방법**: 실제 수업에서는 아래 코드를 그대로 실행해 학생이 입력하는 과정을 보여준다.
# ```python
# name = input("이름을 입력하세요: ")
# ```
# 이 노트북은 `validate_notebooks.py`로 자동 실행되므로, `input()`이 멈추지 않도록 아래 셀에서는 예시 값을 직접 대입한다.

# %%
# 자동 실행 검증에서는 input()이 멈추지 않도록 예시 값을 대입합니다.
# 실제 수업에서는 name = input("이름을 입력하세요: ")으로 대체하세요.
name = "지민"
print(f"안녕하세요, {name}님!")
# Out:
# 안녕하세요, 지민님!

# %% [markdown]
# ## 4단계(도전). 나만의 자기소개 만들기
# **시연 방법**: 학생 한 명을 지목해 실시간으로 입력받아 결과를 함께 확인하면 좋다.

# %%
# 실제 수업에서는 favorite_process = input("좋아하는 공정을 입력하세요: ")으로 대체하세요.
favorite_process = "식각"
print(f"저는 {favorite_process}을(를) 좋아합니다.")
# Out:
# 저는 식각을(를) 좋아합니다.

# %% [markdown]
# ## 5단계. AI에게 질문하며 더 알아보기
# **설명 포인트**: AI 챗봇을 "옆자리 조교"처럼 활용하는 습관을 들이도록 독려한다. 질문 예시를
# 칠판에 적어주고, 학생 한 명을 지목해 실제로 답변을 받아보게 하면 효과적이다.
#
# 질문 예시:
# - "파이썬에서 `=`와 `==`는 어떻게 다른가요?"
# - "f-string 서식 옵션을 더 알려주세요."
# - "input()을 실제 프로그램에서는 어떻게 안전하게 처리하나요?"
# - "웨이퍼·다이·칩 관계를 다른 비유로 설명해주세요."

# %% [markdown]
# ## 6단계. AI에게 코드 생성 요청하고 직접 실행해보기
# **설명 포인트**: AI가 만든 코드에는 아직 배우지 않은 문법(`if`/`else`)이 섞여 나올 수 있다는 점을
# 강조한다 — "AI 코드를 그대로 베끼지 말고 이해하고 써야 한다"는 메시지를 전달하기 좋은 타이밍이다.
#
# 프롬프트 예시: "pass_count, fail_count 변수로 합격률을 계산해서 90% 이상이면 '정상', 아니면
# '점검 필요'라고 출력하는 코드를 만들어줘."
#
# 아래는 AI가 생성해줄 수 있는 예시 코드와 실행 결과다(앞서 만든 `pass_count`, `fail_count`를
# 그대로 재사용한다).

# %%
total = pass_count + fail_count
pass_rate = pass_count / total * 100

if pass_rate >= 90:
    print(f"합격률 {pass_rate:.1f}% → 정상")
else:
    print(f"합격률 {pass_rate:.1f}% → 점검 필요")

# %% [markdown]
# ## 7단계. 연습문제 — 온도·설비 이름으로 문장 만들기
# **설명 포인트**: 1~2단계에서 배운 변수·f-string을 새로운 데이터로 한 번 더 반복 연습시키는
# 단계다. 운영안의 "빠른 학습자용 추가 과제"(온도·설비 변수를 조합한 문장 만들기)를 실제 노트북
# 실습으로 옮긴 것이므로, 빠른 학습자에게는 도전 문제까지, 느린 학습자에게는 첫 번째 셀까지만
# 요구해도 충분하다.

# %%
temp_eq02 = 23.5
temp_eq05 = 24.1
avg_temp = (temp_eq02 + temp_eq05) / 2

print(f"EQ-02 온도: {temp_eq02}도, EQ-05 온도: {temp_eq05}도")
print(f"두 설비의 평균 온도는 {avg_temp:.1f}도입니다.")

# %% [markdown]
# ### 도전. 나만의 문장 만들기
# **시연 방법**: 학생마다 문장 표현이 달라도 괜찮다는 점을 강조 — 정답은 하나가 아니다.

# %%
humidity_eq02 = 45.2
humidity_eq05 = 44.8

print(f"EQ-02: 온도 {temp_eq02}도 · 습도 {humidity_eq02}%")
print(f"EQ-05: 온도 {temp_eq05}도 · 습도 {humidity_eq05}%")

# %% [markdown]
# ## 8단계. AI로 재미있는 미니 프로그램 만들기 🎉
# **설명 포인트**: 과제 2(자기소개 카드)와는 다르게, 이 단계는 "AI에게 재미있는 아이디어를
# 제안받아 직접 실행해보는 경험" 자체가 목적이다. 정확한 코드보다 "AI와 대화하며 프로그램을
# 점점 재미있게 발전시키는 과정"을 즐기도록 유도한다.
#
# 프롬프트 예시: "input()으로 이름을 입력받고, 반도체 공정 운세 문장 리스트 중 하나를 무작위로
# 골라 이름과 함께 출력하는 파이썬 코드를 만들어줘."
#
# **주의 안내**: `random.choice()`처럼 아직 배우지 않은 문법이 나올 수 있다 — 리스트(2차시)·
# 반복문(3차시)에서 다시 만날 표현이니 지금은 미리 구경하는 정도로 충분하다고 안내한다.
#
# 아래는 AI가 생성해줄 수 있는 예시 코드다(자동 실행 검증에서는 `input()` 대신 예시 값을 대입).

# %%
import random

random.seed(42)  # 수업 시연에서는 seed를 빼서 매번 다른 결과가 나오게 해도 좋습니다.

name = "지민"  # 실제로는 input("이름을 입력하세요: ")
fortunes = [
    "오늘은 식각 공정에서 대박이 납니다!",
    "포토 공정에서 살짝 조심하세요.",
    "증착 공정 결과가 아주 좋을 예감입니다.",
    "세정을 꼼꼼히 하면 하루 종일 순조롭습니다.",
    "산화 공정에서 뜻밖의 좋은 소식이 있을 거예요.",
]

today_fortune = random.choice(fortunes)
print(f"{name}님의 오늘의 반도체 공정 운세: {today_fortune}")
