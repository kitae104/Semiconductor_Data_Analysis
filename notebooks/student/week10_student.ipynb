# %% [markdown]
# # 10주차 학생용 실습 — 반도체 공정 데이터 분석 미니 프로젝트
#
# 오늘의 질문: **내가 정한 질문에 이 데이터로 답할 수 있을까?**
#
# > 🚧 이 노트북은 v2 커리큘럼 구성이 확정된 직후 작성된 **개요(skeleton)**입니다. 다룰 단계와 순서는 정해졌지만, 구체적인 코드·설명·빈칸 문항은 아직 채워지지 않았습니다. 구성이 최종 확정되면 이어서 상세 내용을 작성합니다.

# %% [markdown]
# ## 다룰 실습 단계(초안)
#
# 1. 분석 주제 선택(또는 직접 정의)
# 2. 필요한 도구(Pandas/Matplotlib/scikit-learn/Orange3) 선택
# 3. 분석 수행 및 그래프 3개 이상 작성
# 4. 결과 문장 5개 이상, 개선안 2개 이상 정리

# %% [markdown]
# ## Orange3 실습(추가 예정)
#
# 원하면 Orange3만으로, 또는 코드와 섞어서 진행 가능

# %% [markdown]
# ## 데이터
#
# `data/weekly/week10/week10_mini_project_dataset.csv`
