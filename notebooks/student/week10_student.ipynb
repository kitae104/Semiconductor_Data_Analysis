# %% [markdown]
# # 10차시 학생용 실습 — 모델 평가와 새 데이터 예측
#
# 오늘의 질문: **내가 만든 모델은 처음 보는 새로운 데이터에서도 믿을 만할까?**
#
# > 🚧 이 노트북은 v2 커리큘럼 구성이 확정된 직후 작성된 **개요(skeleton)**입니다. 다룰 단계와 순서는 정해졌지만, 구체적인 코드·설명·빈칸 문항은 아직 채워지지 않았습니다. 구성이 최종 확정되면 이어서 상세 내용을 작성합니다.

# %% [markdown]
# ## 다룰 실습 단계(초안)
#
# 1. 9차시에서 학습한 모델을 그대로 이어서 사용
# 2. week09_new_lots_to_predict.csv의 새 로트 불러오기
# 3. predict()로 새 로트의 합격/불합격 예측하기
# 4. 예측 결과를 표로 정리하기
# 5. 1~9차시 핵심 내용을 한 문장씩 되짚기

# %% [markdown]
# ## Orange3로 재확인(추가 예정)
#
# 9차시에서 Orange3로 만든 모델에 같은 새 로트를 넣어 Predictions 위젯으로 예측하고, scikit-learn의 predict() 결과와 비교한다.

# %% [markdown]
# ## 데이터
#
# `data/weekly/week10/week09_new_lots_to_predict.csv`
