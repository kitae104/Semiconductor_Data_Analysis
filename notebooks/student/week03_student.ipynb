# %% [markdown]
# # 3차시 학생용 실습 — 리스트·딕셔너리로 배우는 조건문, 반복문, 함수
#
# 오늘의 질문: **리스트에 담긴 여러 설비 정보를 하나씩 살펴보며, 조건에 맞는 것만 컴퓨터가 골라내게 할 수 있을까?**
#
# `# TODO` 라고 적힌 부분만 직접 채워 넣으면 됩니다.

# %% [markdown]
# ## 1단계. 조건문으로 온도 하나 판정하기

# %%
temperature = 312.6

# TODO: 온도가 305를 초과하면 "온도가 너무 높습니다!"를 출력하세요.
if temperature ____ 305:
    print("온도가 너무 높습니다!")

# %% [markdown]
# ## 2단계. if/elif/else로 등급 매기기

# %%
score = 75

# TODO: 빈칸을 채워 등급을 매기세요. (90이상 A, 80이상 B, 70이상 C, 그 외 D)
if score >= 90:
    grade = "A"
____ score >= 80:
    grade = "B"
elif score >= 70:
    grade = ____
else:
    grade = "D"

print(f"점수 {score}는 {grade}등급입니다.")

# %% [markdown]
# ## 3단계. for로 리스트 순회하기

# %%
temperatures = [295.4, 298.1, 312.6, 301.0, 296.8]

# TODO: for로 temperatures의 값을 모두 출력하세요.
____ temp in temperatures:
    print(temp)

# %% [markdown]
# ## 4단계. for + if로 정상 개수 세기

# %%
normal_count = 0

# TODO: 295~305 범위인 값의 개수를 세어 normal_count에 누적하세요.
for temp in temperatures:
    if 295 <= temp <= 305:
        normal_count ____ 1

print(f"정상 범위인 값은 {normal_count}개입니다.")

# %% [markdown]
# ## 5단계. 딕셔너리의 리스트에서 조건에 맞는 것 골라내기

# %%
equipment_list = [
    {"설비번호": "EQ-01", "공정명": "식각", "온도_섭씨": 301.2},
    {"설비번호": "EQ-02", "공정명": "증착", "온도_섭씨": 308.7},
    {"설비번호": "EQ-03", "공정명": "포토", "온도_섭씨": 297.5},
]

# TODO: 온도가 305를 초과하는 설비번호만 hot_equipment 리스트에 담으세요.
hot_equipment = []
for eq in equipment_list:
    if eq["온도_섭씨"] > ____:
        hot_equipment.____(eq["설비번호"])

print(hot_equipment)

# %% [markdown]
# ## 6단계. 함수 만들기 — 평균 계산 함수

# %%
# TODO: 리스트를 받아 평균을 반환하는 함수를 완성하세요.
def calculate_average(numbers):
    return ____(numbers) / ____(numbers)

print(calculate_average(temperatures))

# %% [markdown]
# ## 7단계. 함수 만들기 — 합격 판정 함수

# %%
# TODO: 295~305 범위면 "합격", 아니면 "불합격"을 반환하는 함수를 완성하세요.
def judge_pass(temp):
    if 295 <= temp <= 305:
        return ____
    else:
        return ____

for temp in temperatures:
    print(f"{temp}도 → {judge_pass(temp)}")

# %% [markdown]
# ## 8단계(종합). 함수 + 반복문으로 여러 로트 판정하기

# %%
lots = [
    {"로트번호": "LOT-0101", "온도_섭씨": 299.5},
    {"로트번호": "LOT-0102", "온도_섭씨": 306.2},
    {"로트번호": "LOT-0103", "온도_섭씨": 301.0},
]

# TODO: judge_pass 함수로 각 로트를 판정하고, 불합격 개수를 fail_count에 누적하세요.
fail_count = 0
for lot in lots:
    result = judge_pass(lot["온도_섭씨"])
    print(f"{lot['로트번호']}: {result}")
    if result == ____:
        fail_count += 1

print(f"불합격 로트 수: {fail_count}개")

# %% [markdown]
# ## 9단계. 오늘의 학습을 한 문장으로 정리하기
#
# > (예시) 조건문은 상황에 따라 다르게 판단하고, 반복문은 여러 값을 하나씩 순회하며, 함수는 반복해서 쓰는 코드를 이름 붙여 재사용한다.

# %% [markdown]
# ## 10단계. AI에게 질문하며 더 알아보기
# 오늘 배운 조건문·반복문·함수에 대해 AI 챗봇에게 질문해서 이해를 넓혀봅시다. 하나 이상 골라
# 물어보고, 새로 알게 된 내용을 다음 셀에 한두 줄로 정리해보세요.
#
# - "for문과 while문은 어떻게 다른가요?"
# - "함수의 매개변수에 기본값을 설정하는 방법이 있나요?"
# - "리스트 컴프리헨션(list comprehension)이 뭔가요?"
# - "재귀 함수(recursive function)가 뭔가요?"

# %% [markdown]
# ✏️ **내가 새로 알게 된 점**: (여기에 AI 답변을 요약해서 적어보세요)

# %% [markdown]
# ## 11단계. AI에게 코드 생성 요청하고 직접 실행해보기
# 아래 프롬프트를 AI에게 그대로 물어보고, AI가 만들어준 코드를 다음 셀에 붙여넣어 실행해보세요.
#
# - 프롬프트 예시: "로트번호와 온도가 담긴 딕셔너리 리스트를 받아서, 합격/불합격 개수를 각각 세어
#   딕셔너리로 반환하는 함수를 만들어줘."
#
# 앞에서 만든 `lots` 리스트를 그대로 사용해도 됩니다.

# %%
# 여기에 AI가 생성한 코드를 붙여넣고 실행해보세요.
