# %% [markdown]
# # 3주차 학생용 실습 — 파이썬 기초 Ⅱ — 조건문, 반복문, 함수
#
# 오늘의 질문: **온도가 정상 범위를 벗어났는지, 사람이 눈으로 보지 않고 컴퓨터가 대신 판단하게 하려면 어떻게 해야 할까?**
#
# > 🚧 이 노트북은 v2 커리큘럼 구성이 확정된 직후 작성된 **개요(skeleton)**입니다. 다룰 단계와 순서는 정해졌지만, 구체적인 코드·설명·빈칸 문항은 아직 채워지지 않았습니다. 구성이 최종 확정되면 이어서 상세 내용을 작성합니다.

# %% [markdown]
# ## 다룰 실습 단계(초안)
#
# 1. 온도 하나를 조건문으로 정상/비정상 판정하기
# 2. for로 리스트 전체를 순회하며 정상 개수 세기
# 3. 평균 계산을 함수로 만들기
# 4. 합격/불합격 판정을 함수로 만들어 여러 로트에 반복 적용하기
# 5. 내가 만든 함수 결과를 4주차에 배울 Pandas 결과와 비교 예고

# %% [markdown]
# ## 데이터
#
# `data/weekly/week03/week03_python_basics_2.csv`
