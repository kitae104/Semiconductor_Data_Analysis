# %% [markdown]
# # 2차시 학생용 실습 — 리스트와 딕셔너리
#
# 오늘의 질문: **여러 개의 측정값을 한 번에 담고, 각 값에 이름표까지 붙이려면 어떻게 해야 할까?**
#
# 이 노트북은 위에서 아래로 순서대로 실행합니다. `# TODO` 라고 적힌 부분만 직접 채워 넣으면 됩니다.

# %% [markdown]
# ## 1단계. 리스트 만들기
# 온도 값 5개를 리스트에 담아봅니다.

# %%
# TODO: 아래 다섯 개의 값을 담은 리스트를 만들어 temperatures에 저장하세요.
# 295.4, 298.1, 312.6, 301.0, 296.8
temperatures = [____, ____, ____, ____, ____]
print(temperatures)

# %% [markdown]
# ## 2단계. 인덱싱으로 값 꺼내기
# 리스트의 첫 번째 값은 인덱스 0입니다.

# %%
# TODO: 빈칸을 채워 첫 번째 값, 세 번째 값, 마지막 값을 각각 출력하세요.
print(temperatures[____])   # 첫 번째 값
print(temperatures[____])   # 세 번째 값
print(temperatures[____])   # 마지막 값(음수 인덱스)

# %% [markdown]
# ## 3단계. 슬라이싱
# `list[시작:끝]`은 끝 인덱스를 포함하지 않습니다.

# %%
# TODO: 인덱스 1~2(298.1, 312.6)만 잘라서 출력하세요.
print(temperatures[____:____])

# %% [markdown]
# **질문**: `temperatures[1:3]`과 `temperatures[1:4]`의 결과는 어떻게 다른가요?
#
# > (여기에 직접 답을 적어보세요)

# %% [markdown]
# ## 4단계. 길이와 추가
# `len()`으로 개수를, `append()`로 새 값 추가를 해봅니다.

# %%
# TODO: 빈칸에 알맞은 메서드/함수 이름을 입력하세요.
print(____(temperatures))     # 리스트 길이
temperatures.____(303.2)      # 끝에 값 추가
print(temperatures)

# %% [markdown]
# ## 5단계. 최댓값·최솟값·평균 계산하기
# `max()`, `min()`, `sum()`을 조합해 평균까지 구해봅니다.

# %%
# TODO: 빈칸을 채워 최댓값, 최솟값, 평균을 계산하고 f-string으로 출력하세요.
highest = ____(temperatures)
lowest = ____(temperatures)
average = sum(temperatures) / ____(temperatures)

print(f"최댓값: {highest}, 최솟값: {lowest}, 평균: {round(average, 1)}")

# %% [markdown]
# ## 6단계. 딕셔너리 만들기
# 설비 1대의 정보를 딕셔너리로 표현합니다.

# %%
# TODO: 설비번호는 "EQ-01", 공정명은 "식각", 온도_섭씨는 301.2로 딕셔너리를 만드세요.
equipment = {
    "설비번호": ____,
    "공정명": ____,
    "온도_섭씨": ____,
}
print(equipment)

# %% [markdown]
# ## 7단계. 키로 값 접근하기

# %%
# TODO: 빈칸에 알맞은 키를 넣어 설비번호와 온도를 각각 출력하세요.
print(equipment[____])
print(equipment[____])

# %% [markdown]
# ## 8단계. 값 수정하기 / 새 키 추가하기

# %%
# TODO: 온도_섭씨 값을 305.5로 수정하고, 압력_Pa라는 새 키에 1012.3을 추가하세요.
equipment["온도_섭씨"] = ____
equipment[____] = 1012.3
print(equipment)

# %% [markdown]
# ## 9단계. 리스트 안에 딕셔너리 담기
# 설비 3대를 '딕셔너리의 리스트'로 표현해봅니다.

# %%
equipment_list = [
    {"설비번호": "EQ-01", "공정명": "식각", "온도_섭씨": 301.2},
    {"설비번호": "EQ-02", "공정명": "증착", "온도_섭씨": 308.7},
    {"설비번호": "EQ-03", "공정명": "포토", "온도_섭씨": 297.5},
]

# TODO: 빈칸을 채워 설비 개수와, 두 번째(인덱스 1) 설비의 공정명을 출력하세요.
print(____(equipment_list))
print(equipment_list[____]["공정명"])

# %% [markdown]
# ## 10단계(도전). 종합 실습 — 나만의 설비 목록 만들기
# 설비 2개를 딕셔너리의 리스트로 만들고, f-string으로 소개 문장을 출력해보세요.

# %%
# TODO: my_equipment 리스트에 설비 딕셔너리 2개를 담고,
# f-string으로 각 설비를 소개하는 문장을 한 줄씩 출력하세요.
my_equipment = [
    {"설비번호": ____, "공정명": ____, "온도_섭씨": ____},
    {"설비번호": ____, "공정명": ____, "온도_섭씨": ____},
]

print(f"{my_equipment[0]['설비번호']} 설비는 {my_equipment[0]['공정명']} 공정입니다.")
print(f"{my_equipment[1]['설비번호']} 설비는 {my_equipment[1]['공정명']} 공정입니다.")

# %% [markdown]
# ## 11단계. 오늘의 학습을 한 문장으로 정리하기
#
# 아래 마크다운 셀을 더블클릭해서 여러분의 문장으로 바꿔보세요.
#
# > (예시) 리스트는 순서로 값을 구분하고, 딕셔너리는 이름표(키)로 값을 구분한다. 리스트 안에 딕셔너리를 담으면 여러 설비 정보를 한 번에 표현할 수 있다.

# %% [markdown]
# ## 12단계. AI에게 질문하며 더 알아보기
# 오늘 배운 리스트·딕셔너리에 대해 AI 챗봇에게 질문해서 이해를 넓혀봅시다. 하나 이상 골라
# 물어보고, 새로 알게 된 내용을 다음 셀에 한두 줄로 정리해보세요.
#
# - "파이썬 리스트와 튜플은 어떻게 다른가요?"
# - "딕셔너리에서 키(key)로 쓸 수 있는 값과 쓸 수 없는 값은 무엇인가요?"
# - "딕셔너리 안에 리스트를 담을 수도 있나요? 예시를 들어주세요."
# - "리스트의 append()와 insert()는 어떻게 다른가요?"

# %% [markdown]
# ✏️ **내가 새로 알게 된 점**: (여기에 AI 답변을 요약해서 적어보세요)

# %% [markdown]
# ## 13단계. AI에게 코드 생성 요청하고 직접 실행해보기
# 아래 프롬프트를 AI에게 그대로 물어보고, AI가 만들어준 코드를 다음 셀에 붙여넣어 실행해보세요.
#
# - 프롬프트 예시: "설비 정보 딕셔너리가 여러 개 담긴 리스트에서, 온도가 가장 높은 설비 하나만
#   찾아주는 코드를 만들어줘."
#
# AI가 `max()`의 `key` 옵션처럼 오늘 배우지 않은 문법을 사용했다면, "이 코드가 어떤 뜻이야?"라고
# 다시 물어보며 이해하고 넘어가세요.

# %%
# 여기에 AI가 생성한 코드를 붙여넣고 실행해보세요.

# %% [markdown]
# ## 14단계. 연습문제 — 압력 리스트와 새 설비 딕셔너리
# 이번엔 새로운 값으로 리스트와 딕셔너리를 다시 연습해봅니다. 아래는 오늘 측정한 압력 값입니다.
#
# `pressures = [1010.2, 1005.4, 1022.9, 998.7, 1011.0]`
#
# 리스트를 만들고, 최댓값·최솟값·평균을 계산해봅니다.

# %%
# TODO: 아래 다섯 개의 값을 담은 리스트를 만들어 pressures에 저장하세요.
# 1010.2, 1005.4, 1022.9, 998.7, 1011.0
pressures = [____, ____, ____, ____, ____]

# TODO: 빈칸을 채워 최댓값, 최솟값, 평균을 계산하고 f-string으로 출력하세요.
highest_p = ____(pressures)
lowest_p = ____(pressures)
average_p = sum(pressures) / ____(pressures)

print(f"최댓값: {highest_p}, 최솟값: {lowest_p}, 평균: {round(average_p, 1)}")

# %% [markdown]
# ### 도전. 새 설비 딕셔너리에 압력 추가하기
# 방금 계산한 평균 압력(`average_p`)을 새 설비 딕셔너리에 담아봅니다.

# %%
# TODO: 설비번호는 "EQ-04", 공정명은 "세정", 온도_섭씨는 299.9로 딕셔너리를 만드세요.
eq04 = {
    "설비번호": ____,
    "공정명": ____,
    "온도_섭씨": ____,
}

# TODO: eq04에 "압력_Pa"라는 새 키로 average_p 값을 추가하세요.
eq04[____] = average_p
print(eq04)

# %% [markdown]
# ## 15단계. AI로 재미있는 미니 프로그램 만들기 🎉 — 오늘의 럭키 설비 뽑기
# 오늘 배운 리스트·딕셔너리로, 실행하면 재미를 느낄 수 있는 나만의 프로그램을 AI에게 만들어달라고
# 요청해봅시다.
#
# 아래 프롬프트를 그대로 AI 챗봇(ChatGPT, Claude 등)에게 물어보고, 만들어준 코드를 다음 셀에
# 붙여넣어 실행해보세요. 실행하기 전에 9단계에서 만든 `equipment_list`에 방금 만든 `eq04`도
# 추가해두면(`equipment_list.append(eq04)`), 네 개 설비 중에서 럭키 설비가 뽑힙니다.
#
# **프롬프트 예시**: "설비 정보 딕셔너리가 여러 개 담긴 리스트(equipment_list)에서, random.choice()로
# 하나를 무작위로 뽑아서 '오늘의 럭키 설비'라는 제목과 함께 설비번호·공정명·온도를 예쁘게 출력하는
# 파이썬 코드를 만들어줘."
#
# **더 놀아보기**:
# - "설비를 2개 더 추가해줘"처럼 요청해서 뽑기 대상을 풍성하게 만들어보세요.
# - 출력을 이모지나 구분선으로 꾸며달라고 요청해도 좋습니다.
# - `random` 모듈 자체는 오늘 처음 보는 표현입니다 — 리스트와 딕셔너리는 오늘 배운 내용이니,
#   `random.choice()`가 리스트 안에서 하나를 무작위로 골라준다는 정도만 이해하고 넘어가도
#   충분합니다.

# %%
# 여기에 AI가 생성한 럭키 설비 뽑기 코드를 붙여넣고 실행해보세요.
