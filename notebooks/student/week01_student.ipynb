# %% [markdown]
# # 1주차 학생용 실습 — 반도체 공정과 데이터 처음 만나기
#
# 오늘의 질문: **반도체는 어떻게 만들어지고, 그 과정은 어떤 기록을 남길까?**
#
# 이 노트북은 위에서 아래로 순서대로 실행합니다. `# TODO` 라고 적힌 부분만 직접 채워 넣으면 됩니다.

# %% [markdown]
# ## 1단계. Pandas 불러오기
# 데이터 분석 도구인 Pandas를 불러옵니다.

# %%
import pandas as pd
print('Pandas 준비 완료')

# %% [markdown]
# ## 2단계. 데이터 읽기
# CSV 파일을 읽어 표(DataFrame) 형태로 저장합니다.
#
# **Colab을 사용한다면**: 왼쪽 파일 아이콘에서 `week01_semiconductor_process_overview.csv`를 업로드한 뒤,
# 아래 경로를 `"week01_semiconductor_process_overview.csv"`로 바꿔서 실행하세요.

# %%
df = pd.read_csv("../../data/weekly/week01/week01_semiconductor_process_overview.csv")
df.head()

# %% [markdown]
# ## 3단계. 데이터 크기와 열 이름 확인하기
# `shape`는 (행 개수, 열 개수)를, `columns`는 열 이름 목록을 알려주는 속성입니다.

# %%
# TODO: 빈칸에 'shape'를 입력해 (행 개수, 열 개수)를 출력하세요.
print(df.____)

# TODO: 빈칸에 'columns'를 입력해 열 이름 목록을 출력하세요.
print(df.____)

# %% [markdown]
# **질문**: 이 데이터는 몇 행, 몇 열인가요? 아래 문장을 완성해보세요.
#
# > 이 데이터는 ___행 ___열로 이루어져 있다.

# %% [markdown]
# ## 4단계. 합격/불합격 개수 세기
# `합격여부` 열에서 값별 개수를 세어봅니다. (1=합격, -1=불합격)
#
# 값별 개수를 세는 메서드 이름은 `value_counts`입니다.

# %%
# TODO: 빈칸에 알맞은 메서드 이름을 입력하세요.
df["합격여부"].____()

# %% [markdown]
# **질문**: 합격은 몇 건, 불합격은 몇 건인가요? 불합격 비율(%)을 계산해보세요.
#
# > 합격 ___건, 불합격 ___건, 불합격 비율 약 ___%

# %% [markdown]
# ## 5단계(도전). 설비별·공정별로도 세어보기
# 4단계에서 사용한 것과 같은 메서드를 다른 열에도 적용해보세요.

# %%
# TODO: '설비번호' 열에 대해 4단계와 같은 방식으로 값별 개수를 세어보세요.
df["설비번호"]

# %%
# TODO: '공정명' 열에 대해서도 값별 개수를 세어보세요.
df["공정명"]

# %% [markdown]
# ## 6단계. 오늘의 분석을 한 문장으로 정리하기
#
# 아래 마크다운 셀을 더블클릭해서 여러분의 문장으로 바꿔보세요.
#
# > (예시) 이번 공정 기록 40건 중 34건(85%)이 합격했고, 6건(15%)이 불합격했다.
