# %% [markdown]
# # 1차시 학생용 실습 — 반도체 공정과 데이터 처음 만나기 + 변수·출력
#
# 오늘의 질문: **반도체는 어떻게 만들어지고, 그 과정은 어떤 기록을 남길까?**
#
# 오늘은 표 전체를 다루는 Pandas 대신, 파이썬으로 값 하나를 다루는 가장 작은 단위인
# **변수**부터 시작합니다. "변수 → f-string 출력 → input() 입력"까지 차근차근 연습합니다.
# Pandas로 이 표를 직접 열어보는 건 4차시부터입니다.
#
# 이 노트북은 위에서 아래로 순서대로 실행합니다. `# TODO` 라고 적힌 부분만 직접 채워 넣으면 됩니다.

# %% [markdown]
# ## 오늘 살펴본 데이터
# 강의 자료에서 `week01_semiconductor_process_overview.csv` 표를 눈으로 미리 살펴봤습니다.
# 그중 `합격여부` 열을 정리하면 **합격 34건, 불합격 6건**이었습니다.
#
# 이 숫자 두 개를 아래에서 변수에 저장해봅니다.

# %% [markdown]
# ## 1단계. 변수 만들고 값 확인하기
# 오늘 살펴본 합격/불합격 개수를 변수에 저장해봅니다. `=`는 오른쪽 값을 왼쪽 이름에 저장하라는 뜻입니다.

# %%
# TODO: pass_count에 34를, fail_count에 6을 저장하세요.
pass_count = ____
fail_count = ____
print(pass_count)
print(fail_count)

# %% [markdown]
# ## 2단계. f-string으로 문장 만들기
# 변수 앞뒤로 문장을 붙여, 값을 문장 속에 자연스럽게 끼워 넣어봅니다.

# %%
# TODO: 빈칸에 알맞은 변수를 넣어 "합격 34건, 불합격 6건입니다."를 출력하세요.
print(f"합격 {____}건, 불합격 {____}건입니다.")

# %% [markdown]
# ## 3단계. input()으로 값 입력받기
# Colab/Jupyter에서 실행하면 입력창이 뜹니다. 이름을 입력해보세요.

# %%
# TODO: input()으로 이름을 입력받아 name 변수에 저장하세요.
name = ____("이름을 입력하세요: ")
print(f"안녕하세요, {name}님!")

# %% [markdown]
# ## 4단계(도전). 나만의 자기소개 만들기
# `input()`과 f-string을 조합해 자기소개 문장을 완성해보세요.

# %%
# TODO: 좋아하는 공정을 입력받아 favorite_process 변수에 저장하고,
# f-string으로 "저는 ○○을(를) 좋아합니다." 문장을 출력하세요.
favorite_process = input("좋아하는 공정을 입력하세요: ")
print(f"저는 {____}을(를) 좋아합니다.")

# %% [markdown]
# ## 5단계. AI에게 질문하며 더 알아보기
# 오늘 배운 변수·자료형·f-string·input()에 대해 AI 챗봇(ChatGPT, Claude 등)에게 질문해서 이해를
# 넓혀봅시다. 아래 질문 중 하나 이상을 골라 물어보고, 새로 알게 된 내용을 다음 셀에 한두 줄로
# 정리해보세요.
#
# - "파이썬에서 `=`와 `==`는 어떻게 다른가요? 예시 코드와 함께 설명해주세요."
# - "f-string에서 `:.1f` 말고 어떤 서식 옵션들이 있나요?"
# - "`input()`으로 받은 값을 실제 프로그램에서는 어떻게 안전하게 처리하나요?"
# - "웨이퍼, 다이, 칩의 관계를 다른 비유로 설명해주세요."

# %% [markdown]
# ✏️ **내가 새로 알게 된 점**: (여기에 AI 답변을 요약해서 적어보세요)

# %% [markdown]
# ## 6단계. AI에게 코드 생성 요청하고 직접 실행해보기
# 아래 프롬프트를 AI에게 그대로 물어보고, AI가 만들어준 코드를 다음 셀에 붙여넣어 실행해보세요.
#
# - 프롬프트 예시: "pass_count, fail_count 변수로 합격률을 계산해서 90% 이상이면 '정상', 아니면
#   '점검 필요'라고 출력하는 파이썬 코드를 만들어줘."
#
# **실행 결과가 이상하면 한 줄씩 읽으며 무슨 뜻인지 확인해보세요** — 아직 배우지 않은 문법(예:
# `if`/`else`)이 섞여 있을 수 있습니다. 조건문은 3차시에서 자세히 배웁니다.

# %%
# 여기에 AI가 생성한 코드를 붙여넣고 실행해보세요.

# %% [markdown]
# ## 7단계. 연습문제 — 온도·설비 이름으로 문장 만들기
# 이번엔 새로운 값으로 직접 연습해봅니다. 아래는 두 설비의 오늘 측정값입니다.
#
# | 설비 | 온도(°C) | 습도(%) |
# | --- | --- | --- |
# | EQ-02 | 23.5 | 45.2 |
# | EQ-05 | 24.1 | 44.8 |
#
# 두 설비의 온도를 각각 변수에 저장하고, 평균 온도를 계산해 f-string으로 출력해봅니다.

# %%
# TODO: EQ-02와 EQ-05의 온도를 각각 temp_eq02, temp_eq05 변수에 저장하세요.
temp_eq02 = ____
temp_eq05 = ____

# TODO: 두 온도의 평균을 avg_temp 변수에 저장하세요. (힌트: (a + b) / 2)
avg_temp = ____

print(f"EQ-02 온도: {temp_eq02}도, EQ-05 온도: {temp_eq05}도")
print(f"두 설비의 평균 온도는 {avg_temp:.1f}도입니다.")

# %% [markdown]
# ### 도전. 나만의 문장 만들기
# 습도(`humidity_eq02 = 45.2`, `humidity_eq05 = 44.8`)도 변수로 저장하고, 온도와 습도를 모두
# 포함한 나만의 f-string 문장을 만들어 출력해보세요. (`:.1f` 서식을 하나 이상 사용해보세요.)

# %%
# TODO: humidity_eq02, humidity_eq05 변수를 만들고,
# 온도+습도를 모두 포함한 문장을 자유롭게 f-string으로 출력해보세요.
humidity_eq02 = ____
humidity_eq05 = ____

print(f"____")

# %% [markdown]
# ## 8단계. AI로 재미있는 미니 프로그램 만들기 🎉
# 오늘 배운 변수·f-string·input()으로, 직접 실행하면서 재미를 느낄 수 있는 나만의 프로그램을
# AI에게 만들어달라고 요청해봅시다.
#
# 아래 프롬프트를 그대로 AI 챗봇(ChatGPT, Claude 등)에게 물어보고, 만들어준 코드를 다음 셀에
# 붙여넣어 실행해보세요.
#
# **프롬프트 예시**: "input()으로 이름을 입력받고, 반도체 공정 운세 문장 리스트
# (예: '오늘은 식각 공정에서 대박이 납니다!', '포토 공정에서 살짝 조심하세요' 등 5개 정도) 중
# 하나를 무작위로 골라 이름과 함께 재미있게 출력하는 파이썬 코드를 만들어줘. `random` 모듈을
# 사용해도 좋아."
#
# **실행 후 더 놀아보기**:
# - "운세 문장을 반도체 공정 이름(증착/식각/포토/세정/산화)마다 다르게 5개씩 만들어줘"처럼
#   추가로 요청해서 내용을 풍성하게 만들어보세요.
# - 코드에 `random.choice()`처럼 아직 배우지 않은 표현이 나올 수 있습니다 — 리스트는 2차시,
#   반복문은 3차시에서 배우니 지금은 "이런 것도 있구나" 정도로 미리 구경하면 충분합니다.

# %%
# 여기에 AI가 생성한 반도체 공정 운세 코드를 붙여넣고 실행해보세요.
