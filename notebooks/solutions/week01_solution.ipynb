# %% [markdown]
# # 1차시 정답 Notebook — 반도체 공정과 데이터 처음 만나기 + 변수·출력
#
# 오늘은 Pandas 없이 진행합니다(Pandas는 4차시부터). 강의 자료에서 데이터를 눈으로 미리 살펴본 뒤,
# 그 결과(합격 32건/불합격 8건)를 변수에 저장하는 것으로 시작합니다.

# %% [markdown]
# ## 오늘 살펴본 데이터
# 강의 자료에서 `week01_semiconductor_process_overview.csv` 표를 눈으로 미리 살펴봤습니다.
# 그중 `합격여부` 열을 정리하면 **합격 32건, 불합격 8건(불합격 비율 20%)**이었습니다.
#
# 이 숫자 두 개를 아래에서 변수에 저장합니다.

# %% [markdown]
# ## 1단계. 변수 만들고 값 확인하기

# %%
pass_count = 32
fail_count = 8
print(pass_count)
print(fail_count)
# Out:
# 32
# 8

# %% [markdown]
# ## 2단계. f-string으로 문장 만들기

# %%
print(f"합격 {pass_count}건, 불합격 {fail_count}건입니다.")
# Out:
# 합격 32건, 불합격 8건입니다.

# %% [markdown]
# ## 3단계. input()으로 값 입력받기
#
# > 참고: 자동 실행 환경에서는 input()이 멈추지 않도록 예시 값을 대신 사용합니다. 직접 실행할 때는 `name = input("이름을 입력하세요: ")`을 사용하세요.

# %%
name = "지민"  # 실제로는 input("이름을 입력하세요: ")
print(f"안녕하세요, {name}님!")
# Out:
# 안녕하세요, 지민님!

# %% [markdown]
# ## 4단계(도전). 나만의 자기소개 만들기

# %%
favorite_process = "식각"  # 실제로는 input("좋아하는 공정을 입력하세요: ")
print(f"저는 {favorite_process}을(를) 좋아합니다.")
# Out:
# 저는 식각을(를) 좋아합니다.

# %% [markdown]
# ## 5단계. AI에게 질문하며 더 알아보기
# 오늘 배운 변수·자료형·f-string·input()에 대해 AI 챗봇에게 질문해 이해를 넓혀봅니다.
#
# 질문 예시:
# - "파이썬에서 `=`와 `==`는 어떻게 다른가요?"
# - "f-string 서식 옵션을 더 알려주세요."
# - "input()을 실제 프로그램에서는 어떻게 안전하게 처리하나요?"
# - "웨이퍼·다이·칩 관계를 다른 비유로 설명해주세요."

# %% [markdown]
# ## 6단계. AI에게 코드 생성 요청하고 직접 실행해보기
# 프롬프트 예시: "pass_count, fail_count 변수로 합격률을 계산해서 90% 이상이면 '정상', 아니면
# '점검 필요'라고 출력하는 코드를 만들어줘."
#
# 아래는 AI가 생성해줄 수 있는 예시 코드와 실행 결과입니다(앞서 만든 `pass_count`, `fail_count`를
# 그대로 재사용합니다).

# %%
total = pass_count + fail_count
pass_rate = pass_count / total * 100

if pass_rate >= 90:
    print(f"합격률 {pass_rate:.1f}% → 정상")
else:
    print(f"합격률 {pass_rate:.1f}% → 점검 필요")
# Out:
# 합격률 80.0% → 점검 필요

# %% [markdown]
# ## 7단계. 연습문제 — 온도·설비 이름으로 문장 만들기

# %%
temp_eq02 = 23.5
temp_eq05 = 24.1
avg_temp = (temp_eq02 + temp_eq05) / 2

print(f"EQ-02 온도: {temp_eq02}도, EQ-05 온도: {temp_eq05}도")
print(f"두 설비의 평균 온도는 {avg_temp:.1f}도입니다.")

humidity_eq02 = 45.2
humidity_eq05 = 44.8

print(f"EQ-02: 온도 {temp_eq02}도 · 습도 {humidity_eq02}%")
print(f"EQ-05: 온도 {temp_eq05}도 · 습도 {humidity_eq05}%")
# Out:
# EQ-02 온도: 23.5도, EQ-05 온도: 24.1도
# 두 설비의 평균 온도는 23.8도입니다.
# EQ-02: 온도 23.5도 · 습도 45.2%
# EQ-05: 온도 24.1도 · 습도 44.8%

# %% [markdown]
# ## 8단계. AI로 재미있는 미니 프로그램 만들기 🎉
# 프롬프트 예시: "input()으로 이름을 입력받고, 반도체 공정 운세 문장 리스트 중 하나를 무작위로
# 골라 이름과 함께 출력하는 파이썬 코드를 만들어줘."

# %%
import random

random.seed(42)

name = "지민"  # 실제로는 input("이름을 입력하세요: ")
fortunes = [
    "오늘은 식각 공정에서 대박이 납니다!",
    "포토 공정에서 살짝 조심하세요.",
    "증착 공정 결과가 아주 좋을 예감입니다.",
    "세정을 꼼꼼히 하면 하루 종일 순조롭습니다.",
    "산화 공정에서 뜻밖의 좋은 소식이 있을 거예요.",
]

today_fortune = random.choice(fortunes)
print(f"{name}님의 오늘의 반도체 공정 운세: {today_fortune}")
# Out:
# 지민님의 오늘의 반도체 공정 운세: 오늘은 식각 공정에서 대박이 납니다!
